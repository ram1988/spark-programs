# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as func
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, LongType
import sys

# %%
def computePearsonCorrelation(spark, data):
    
    # Compute numerator, denominator and numPairs columns
    calculateRatingsMeans = data \
                        .select(func.avg(func.col("rating1")).alias("avg_rating1"), \
                        func.avg(func.col("rating2")).alias("avg_rating2"))  
    
    calculateRatingsMeans = calculateRatingsMeans.take(1)
    avg_rating1 = calculateRatingsMeans[0].avg_rating1
    avg_rating2 = calculateRatingsMeans[0].avg_rating2
    
    print("avg_rating1....")
    print(calculateRatingsMeans)

    pairScores = data \
      .withColumn("rating1-rating1_avg", func.col("rating1")-avg_rating1) \
      .withColumn("rating2-rating2_avg", func.col("rating2")-avg_rating2)
        
    print(pairScores)
    
    pairScores = pairScores \
      .withColumn("(rating1-rating1_avg)2", func.col("rating1-rating1_avg")*func.col("rating1-rating1_avg")) \
      .withColumn("(rating2-rating2_avg)2", func.col("rating2-rating2_avg")*func.col("rating2-rating2_avg"))
    
    calculatePearsonCorrelation = pairScores.groupBy("movie1", "movie2").\
                                agg(func.sum(func.col("rating1-rating1_avg")*func.col("rating2-rating2_avg")).alias("numerator"),\
                                    func.sqrt(func.sum(func.col("(rating1-rating1_avg)2"))*func.sum(func.col("(rating2-rating2_avg)2"))).alias("denominator"),\
                                    func.count(func.col("rating1-rating1_avg")).alias("numPairs")
                                )
        
    result = calculatePearsonCorrelation \
            .withColumn("score", \
            func.when(func.col("denominator") != 0, func.col("numerator") / func.col("denominator")) \
              .otherwise(0) \
          ).select("movie1", "movie2", "score", "numPairs")


    return result

# %%
# Get movie name by given movie id 
def getMovieName(movieNames, movieId):
    result = movieNames.filter(func.col("movieID") == movieId) \
        .select("movieTitle").collect()[0]

    return result[0]

# %%
spark = SparkSession.builder.appName("MovieSimilarities").master("local[*]").getOrCreate()

movieNamesSchema = StructType([ \
                               StructField("movieID", IntegerType(), True), \
                               StructField("movieTitle", StringType(), True) \
                               ])
    
moviesSchema = StructType([ \
                     StructField("userID", IntegerType(), True), \
                     StructField("movieID", IntegerType(), True), \
                     StructField("rating", IntegerType(), True), \
                     StructField("timestamp", LongType(), True)])

# %%
# Create a broadcast dataset of movieID and movieTitle.
# Apply ISO-885901 charset
movieNames = spark.read \
      .option("sep", "|") \
      .option("charset", "ISO-8859-1") \
      .schema(movieNamesSchema) \
      .csv("./ml-100k/u.item")

# Load up movie data as dataset
movies = spark.read \
      .option("sep", "\t") \
      .schema(moviesSchema) \
      .csv("./ml-100k/u.data")


ratings = movies.select("userId", "movieId", "rating")

# %%
# Emit every movie rated together by the same user.
# Self-join to find every combination.
# Select movie pairs and rating pairs
moviePairs = ratings.alias("ratings1") \
      .join(ratings.alias("ratings2"), (func.col("ratings1.userId") == func.col("ratings2.userId")) \
            & (func.col("ratings1.movieId") < func.col("ratings2.movieId"))) \
      .select(func.col("ratings1.movieId").alias("movie1"), \
        func.col("ratings2.movieId").alias("movie2"), \
        func.col("ratings1.rating").alias("rating1"), \
        func.col("ratings2.rating").alias("rating2"))
moviePairSimilarities = computePearsonCorrelation(spark, moviePairs).cache()
# Out:
# avg_rating1....
# [Row(avg_rating1=3.5387608221996207, avg_rating2=3.328259773784263)]
# DataFrame[movie1: int, movie2: int, rating1: int, rating2: int, rating1-rating1_avg: double, rating2-rating2_avg: double]

# %%
moviePairSimilarities.show(10)
# Out:
# +------+------+--------------------+--------+
# |movie1|movie2|               score|numPairs|
# +------+------+--------------------+--------+
# |    51|   924| 0.48510926322433373|      15|
# |   451|   529|-0.25775258245291877|      30|
# |    86|   318| 0.25969042145386984|      95|
# |    40|   167| 0.21993755394170952|      23|
# |   274|  1211| 0.47952217480856885|       7|
# |  1042|  1067|  0.9843770697791376|       2|
# |   118|   946| 0.18713050345791857|      40|
# |   234|   461| 0.25696289013597445|      54|
# |    88|   523| 0.16214675211898022|      74|
# |   796|  1036|  0.6667465315739322|       8|
# +------+------+--------------------+--------+
# only showing top 10 rows

# %%
scoreThreshold = 0.7
coOccurrenceThreshold = 50.0

movieID = 51

# Filter for movies with this sim that are "good" as defined by
# our quality thresholds above
filteredResults = moviePairSimilarities.filter( \
    ((func.col("movie1") == movieID) | (func.col("movie2") == movieID)) & \
      (func.col("score") > scoreThreshold))

# Sort by quality score.
results = filteredResults.sort(func.col("score").desc()).take(200)

print ("Top 10 similar movies for " + getMovieName(movieNames, movieID))

for result in results:
    # Display the similarity result that isn't the movie we're looking at
    similarMovieID = result.movie1
    if (similarMovieID == movieID):
      similarMovieID = result.movie2

    print(getMovieName(movieNames, similarMovieID) + "\tscore: " \
          + str(result.score) + "\tstrength: " + str(result.numPairs))
# Out:
# Top 10 similar movies for Legends of the Fall (1994)
# Shadows (Cienie) (1988)	score: 1.0000000000000002	strength: 1
# Hugo Pool (1997)	score: 1.0000000000000002	strength: 1
# Total Eclipse (1995)	score: 1.0000000000000002	strength: 1
# Pyromaniac's Love Story, A (1995)	score: 1.0000000000000002	strength: 1
# Liebelei (1933)	score: 1.0000000000000002	strength: 1
# Duoluo tianshi (1995)	score: 1.0000000000000002	strength: 1
# Careful (1992)	score: 1.0000000000000002	strength: 1
# It Takes Two (1995)	score: 1.0000000000000002	strength: 1
# Last Time I Committed Suicide, The (1997)	score: 1.0000000000000002	strength: 1
# Two Deaths (1995)	score: 1.0000000000000002	strength: 1
# Kim (1950)	score: 1.0000000000000002	strength: 1
# Hunted, The (1995)	score: 1.0000000000000002	strength: 1
# Hear My Song (1991)	score: 1.0000000000000002	strength: 1
# Invitation, The (Zaproszenie) (1986)	score: 1.0000000000000002	strength: 1
# Yankee Zulu (1994)	score: 1.0000000000000002	strength: 1
# Journey of August King, The (1995)	score: 1.0000000000000002	strength: 1
# Woman in Question, The (1950)	score: 1.0000000000000002	strength: 1
# Lashou shentan (1992)	score: 1.0000000000000002	strength: 1
# Dingo (1992)	score: 1.0000000000000002	strength: 1
# Bonheur, Le (1965)	score: 1.0000000000000002	strength: 1
# Daens (1992)	score: 1.0000000000000002	strength: 1
# Spirits of the Dead (Tre passi nel delirio) (1968)	score: 1.0000000000000002	strength: 1
# Germinal (1993)	score: 1.0000000000000002	strength: 1
# Stars Fell on Henrietta, The (1995)	score: 1.0000000000000002	strength: 1
# Glass Shield, The (1994)	score: 1.0000000000000002	strength: 1
# Even Cowgirls Get the Blues (1993)	score: 1.0000000000000002	strength: 1
# Nina Takes a Lover (1994)	score: 1.0000000000000002	strength: 1
# Sliding Doors (1998)	score: 1.0000000000000002	strength: 1
# Shooting Fish (1997)	score: 1.0000000000000002	strength: 1
# Stranger in the House (1997)	score: 1.0000000000000002	strength: 1
# Condition Red (1995)	score: 1.0000000000000002	strength: 1
# Hungarian Fairy Tale, A (1987)	score: 1.0000000000000002	strength: 1
# Eye of Vichy, The (Oeil de Vichy, L') (1993)	score: 1.0000000000000002	strength: 1
# For Ever Mozart (1996)	score: 1.0000000000000002	strength: 1
# Man from Down Under, The (1943)	score: 1.0000000000000002	strength: 1
# Boy's Life 2 (1997)	score: 1.0000000000000002	strength: 1
# Somebody to Love (1994)	score: 1.0000000000000002	strength: 1
# Squeeze (1996)	score: 1.0000000000000002	strength: 1
# Magic Hour, The (1998)	score: 1.0000000000000002	strength: 1
# Delta of Venus (1994)	score: 1.0000000000000002	strength: 1
# Tigrero: A Film That Was Never Made (1994)	score: 1.0000000000000002	strength: 1
# Symphonie pastorale, La (1946)	score: 1.0000000000000002	strength: 1
# Terror in a Texas Town (1958)	score: 1.0000000000000002	strength: 1
# Wend Kuuni (God's Gift) (1982)	score: 1.0000000000000002	strength: 1
# T-Men (1947)	score: 1.0000000000000002	strength: 1
# Quartier Mozart (1992)	score: 1.0000000000000002	strength: 1
# Swept from the Sea (1997)	score: 1.0000000000000002	strength: 1
# I, Worst of All (Yo, la peor de todas) (1990)	score: 1.0000000000000002	strength: 1
# Salut cousin! (1996)	score: 1.0000000000000002	strength: 1
# C'est arrivé près de chez vous (1992)	score: 1.0000000000000002	strength: 1
# To Have, or Not (1995)	score: 1.0000000000000002	strength: 1
# Boys in Venice (1996)	score: 1.0000000000000002	strength: 1
# Catwalk (1995)	score: 1.0000000000000002	strength: 1
# Vermont Is For Lovers (1992)	score: 1.0000000000000002	strength: 1
# Bushwhacked (1995)	score: 1.0000000000000002	strength: 1
# Killer (Bulletproof Heart) (1994)	score: 1.0000000000000002	strength: 1
# Mighty, The (1998)	score: 1.0000000000000002	strength: 1
# Baton Rouge (1988)	score: 1.0000000000000002	strength: 1
# Secret Adventures of Tom Thumb, The (1993)	score: 1.0000000000000002	strength: 1
# Carmen Miranda: Bananas Is My Business (1994)	score: 1.0000000000000002	strength: 1
# Hostile Intentions (1994)	score: 1.0000000000000002	strength: 1
# Babyfever (1994)	score: 1.0000000000000002	strength: 1
# 1-900 (1994)	score: 1.0000000000000002	strength: 1
# Touki Bouki (Journey of the Hyena) (1973)	score: 1.0000000000000002	strength: 1
# The Courtyard (1995)	score: 1.0000000000000002	strength: 1
# Promise, The (Versprechen, Das) (1994)	score: 1.0000000000000002	strength: 1
# Pharaoh's Army (1995)	score: 1.0000000000000002	strength: 1
# Death in the Garden (Mort en ce jardin, La) (1956)	score: 1.0000000000000002	strength: 1
# Two Bits (1995)	score: 1.0000000000000002	strength: 1
# Jerky Boys, The (1994)	score: 1.0000000000000002	strength: 1
# Schizopolis (1996)	score: 1.0000000000000002	strength: 1
# Shooter, The (1995)	score: 1.0000000000000002	strength: 1
# To Cross the Rubicon (1991)	score: 1.0000000000000002	strength: 1
# Vie est belle, La (Life is Rosey) (1987)	score: 1.0000000000000002	strength: 1
# Horse Whisperer, The (1998)	score: 1.0000000000000002	strength: 1
# Pushing Hands (1992)	score: 1.0000000000000002	strength: 1
# Grateful Dead (1995)	score: 1.0	strength: 1
# Quiet Room, The (1996)	score: 1.0	strength: 1
# Guantanamera (1994)	score: 1.0	strength: 1
# Hurricane Streets (1998)	score: 1.0	strength: 1
# New Jersey Drive (1995)	score: 1.0	strength: 1
# Normal Life (1996)	score: 1.0	strength: 1
# Big One, The (1997)	score: 1.0	strength: 1
# Pompatus of Love, The (1996)	score: 1.0	strength: 1
# Hate (Haine, La) (1995)	score: 1.0	strength: 1
# Gabbeh (1996)	score: 1.0	strength: 1
# One Night Stand (1997)	score: 1.0	strength: 1
# Full Speed (1996)	score: 1.0	strength: 1
# Dream With the Fishes (1997)	score: 1.0	strength: 1
# Fast, Cheap & Out of Control (1997)	score: 1.0	strength: 1
# Loch Ness (1995)	score: 1.0	strength: 1
# Inkwell, The (1994)	score: 1.0	strength: 1
# Romper Stomper (1992)	score: 1.0	strength: 1
# Wonderful, Horrible Life of Leni Riefenstahl, The (1993)	score: 1.0	strength: 1
# Power 98 (1995)	score: 1.0	strength: 1
# Two Friends (1986) 	score: 1.0	strength: 1
# Bloody Child, The (1996)	score: 1.0	strength: 1
# Home Alone 3 (1997)	score: 1.0	strength: 2
# Á köldum klaka (Cold Fever) (1994)	score: 1.0	strength: 1
# Caro Diario (Dear Diary) (1994)	score: 1.0	strength: 1
# Fire on the Mountain (1996)	score: 1.0	strength: 1
# Drunks (1995)	score: 1.0	strength: 2
# Designated Mourner, The (1997)	score: 1.0	strength: 1
# Mr. Magoo (1997)	score: 1.0	strength: 2
# When Night Is Falling (1995)	score: 1.0	strength: 2
# Bad Moon (1996)	score: 1.0	strength: 1
# 8 Seconds (1994)	score: 1.0	strength: 1
# Selena (1997)	score: 1.0	strength: 1
# Thin Line Between Love and Hate, A (1996)	score: 1.0	strength: 1
# Wild America (1997)	score: 1.0	strength: 1
# Firestorm (1998)	score: 1.0	strength: 1
# My Favorite Season (1993)	score: 1.0	strength: 1
# Ayn Rand: A Sense of Life (1997)	score: 1.0	strength: 1
# Prefontaine (1997)	score: 1.0	strength: 2
# Story of Xinghua, The (1993)	score: 1.0	strength: 1
# Sudden Manhattan (1996)	score: 1.0	strength: 1
# Time Tracers (1995)	score: 1.0	strength: 1
# Foreign Student (1994)	score: 1.0	strength: 1
# Frankie Starlight (1995)	score: 1.0	strength: 1
# Dadetown (1995)	score: 1.0	strength: 1
# Price Above Rubies, A (1998)	score: 1.0	strength: 1
# That Darn Cat! (1997)	score: 1.0	strength: 1
# Police Story 4: Project S (Chao ji ji hua) (1993)	score: 1.0	strength: 1
# Good Man in Africa, A (1994)	score: 1.0	strength: 1
# Hana-bi (1997)	score: 1.0	strength: 1
# Paradise Road (1997)	score: 1.0	strength: 1
# Incognito (1997)	score: 1.0	strength: 1
# Paris, France (1993)	score: 1.0	strength: 1
# Kika (1993)	score: 1.0	strength: 1
# Purple Noon (1960)	score: 1.0	strength: 1
# Designated Mourner, The (1997)	score: 1.0	strength: 1
# Buddy (1997)	score: 1.0	strength: 1
# Fall (1997)	score: 1.0	strength: 1
# Raw Deal (1948)	score: 1.0	strength: 1
# Hurricane Streets (1998)	score: 1.0	strength: 1
# Star Maker, The (Uomo delle stelle, L') (1995)	score: 1.0	strength: 1
# Angel and the Badman (1947)	score: 1.0	strength: 1
# Love and Other Catastrophes (1996)	score: 1.0	strength: 1
# Phantoms (1998)	score: 1.0	strength: 1
# Frisk (1995)	score: 1.0	strength: 1
# Last Summer in the Hamptons (1995)	score: 1.0	strength: 2
# Savage Nights (Nuits fauves, Les) (1992)	score: 1.0	strength: 1
# Vermin (1998)	score: 1.0	strength: 1
# Stonewall (1995)	score: 1.0	strength: 1
# Etz Hadomim Tafus (Under the Domin Tree) (1994)	score: 1.0	strength: 1
# Neon Bible, The (1995)	score: 1.0	strength: 1
# Adventures of Pinocchio, The (1996)	score: 1.0	strength: 1
# In the Line of Duty 2 (1987)	score: 1.0	strength: 1
# Prisoner of the Mountains (Kavkazsky Plennik) (1996)	score: 1.0	strength: 1
# Fille seule, La (A Single Girl) (1995)	score: 1.0	strength: 1
# Party Girl (1995)	score: 1.0	strength: 2
# Rhyme & Reason (1997)	score: 1.0	strength: 1
# All Over Me (1997)	score: 1.0	strength: 1
# Mr. Jones (1993)	score: 1.0	strength: 1
# Girls Town (1996)	score: 1.0	strength: 1
# Heavy (1995)	score: 1.0	strength: 2
# You So Crazy (1994)	score: 1.0	strength: 1
# Flower of My Secret, The (Flor de mi secreto, La) (1995)	score: 1.0	strength: 1
# Lamerica (1994)	score: 1.0	strength: 1
# Deceiver (1997)	score: 1.0	strength: 1
# Thieves (Voleurs, Les) (1996)	score: 1.0	strength: 1
# House of Yes, The (1997)	score: 1.0	strength: 1
# Nénette et Boni (1996)	score: 1.0	strength: 1
# Eighth Day, The (1996)	score: 1.0	strength: 1
# Switchblade Sisters (1975)	score: 1.0	strength: 1
# Albino Alligator (1996)	score: 1.0	strength: 1
# Nico Icon (1995)	score: 1.0	strength: 1
# Metisse (Café au Lait) (1993)	score: 1.0	strength: 1
# Rendezvous in Paris (Rendez-vous de Paris, Les) (1995)	score: 1.0	strength: 1
# Of Love and Shadows (1994)	score: 1.0	strength: 1
# Wild Reeds (1994)	score: 1.0	strength: 2
# Year of the Horse (1997)	score: 1.0	strength: 1
# Paris Was a Woman (1995)	score: 1.0	strength: 1
# Men With Guns (1997)	score: 1.0	strength: 1
# Love Serenade (1996)	score: 1.0	strength: 1
# 3 Ninjas: High Noon At Mega Mountain (1998)	score: 1.0	strength: 1
# Infinity (1996)	score: 1.0	strength: 1
# Nelly & Monsieur Arnaud (1995)	score: 1.0	strength: 1
# Simple Wish, A (1997)	score: 1.0	strength: 1
# Contempt (Mépris, Le) (1963)	score: 1.0	strength: 1
# Land and Freedom (Tierra y libertad) (1995)	score: 1.0	strength: 1
# An Unforgettable Summer (1994)	score: 1.0	strength: 1
# Niagara, Niagara (1997)	score: 1.0	strength: 1
# Ed's Next Move (1996)	score: 1.0	strength: 1
# Scream of Stone (Schrei aus Stein) (1991)	score: 1.0	strength: 1
# Silence of the Palace, The (Saimt el Qusur) (1994)	score: 1.0	strength: 1
# Hard Eight (1996)	score: 1.0	strength: 1
# Dangerous Ground (1997)	score: 1.0	strength: 1
# Broken English (1996)	score: 1.0	strength: 1
# Daytrippers, The (1996)	score: 1.0	strength: 1
# Bent (1997)	score: 1.0	strength: 1
# Big Squeeze, The (1996)	score: 1.0	strength: 1
# Telling Lies in America (1997)	score: 1.0	strength: 1
# Children of the Corn: The Gathering (1996)	score: 1.0	strength: 2
# Cement Garden, The (1993)	score: 1.0	strength: 1
# Show, The (1995)	score: 1.0	strength: 1
# I Can't Sleep (J'ai pas sommeil) (1994)	score: 1.0	strength: 1
# Nightwatch (1997)	score: 1.0	strength: 1
# S.F.W. (1994)	score: 1.0	strength: 1
# Maya Lin: A Strong Clear Vision (1994)	score: 0.9999999999999999	strength: 1
